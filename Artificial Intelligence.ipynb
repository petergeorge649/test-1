# %% [markdown]
# 1) In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue. Here is an example if you are not sure what to look for.
#
# 2) use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %%
from IPython.display import Image

# %% [markdown]
# https://www.nytimes.com/2018/02/09/technology/facial-recognition-race-artificial-intelligence.html
#
# Ethical issues with computer vision applications
#
# Based on the article there so many developments when it comes to Artificial Intelligence, however these development come with different flaws, which are some how considered to be caused by ethical issues with computer vision applications. For instance this article on Newyork times highlighted that "When the person in the photo is a white man, the software is right 99 percent of the time". While the darker skins computer tend to give inaccurate results or errors
#
# The article went further identifying errors happened from different artificial intelligence companies for example ,in Google it was identified that African Americans are recognized as “gorillas.” In the google picture application articficial intelligence software.
#
#
# This shows that despite the development in the artificial intelligence, a lot need to be done and invested in this area.

# %%
Image('download.png')

# %% [markdown]
# Summary
#
# I asked the program to show two people watching television. This is spectacular the program managed to identify the request.However the context of the deliverable is so poor, because of poor picture quality it becomes very difficult to identify the items and people from the picture.
